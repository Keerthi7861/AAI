# %%
# ======================================================
# Experiment 2: 70–30 Train–Test Split (No Validation)
# Credit Card Fraud Detection using DNN
# ======================================================

# ----------------------
# 1. Imports
# ----------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    average_precision_score
)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# ----------------------
# 2. Load Dataset (CSV)
# ----------------------
# Make sure creditcard.csv is in the same directory
df = pd.read_csv(r"C:\Users\23adsb58\Downloads\creditcard.csv")

print("Dataset shape:", df.shape)
print(df["Class"].value_counts())

# ----------------------
# 3. Feature / Target Split
# ----------------------
X = df.drop("Class", axis=1)
y = df["Class"]

# ----------------------
# 4. Feature Scaling
# ----------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ----------------------
# 5. Handle Class Imbalance (Class Weights)
# ----------------------
neg, pos = np.bincount(y)
total = neg + pos

class_weight = {
    0: total / (2 * neg),
    1: total / (2 * pos)
}

print("Class weights:", class_weight)

# ----------------------
# 6. Train–Test Split (70–30)
# ----------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.30,
    stratify=y,
    random_state=42
)

print("Training samples:", X_train.shape[0])
print("Test samples:", X_test.shape[0])

# ----------------------
# 7. Build Deep Neural Network
# ----------------------
def build_dnn():
    model = Sequential([
        Dense(128, activation="relu", input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(64, activation="relu"),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation="relu"),
        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

model_exp2 = build_dnn()
model_exp2.summary()

# ----------------------
# 8. Train Model
# ----------------------
history2 = model_exp2.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=2048,
    class_weight=class_weight,
    verbose=2
)

# ----------------------
# 9. Plot Training Loss
# ----------------------
plt.figure(figsize=(6,4))
plt.plot(history2.history["loss"], label="Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Experiment 2 (70–30) - Training Loss")
plt.legend()
plt.show()

# ----------------------
# 10. Model Evaluation
# ----------------------
y_pred_prob = model_exp2.predict(X_test).ravel()
y_pred = (y_pred_prob > 0.5).astype(int)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Experiment 2 - Confusion Matrix")
plt.show()

# ----------------------
# 11. ROC-AUC
# ----------------------
roc_auc = roc_auc_score(y_test, y_pred_prob)
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

plt.figure(figsize=(5,4))
plt.plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Experiment 2 - ROC Curve")
plt.legend()
plt.show()

# ----------------------
# 12. Precision–Recall AUC
# ----------------------
pr_auc = average_precision_score(y_test, y_pred_prob)
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)

plt.figure(figsize=(5,4))
plt.plot(recall, precision, label=f"PR-AUC = {pr_auc:.4f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Experiment 2 - Precision–Recall Curve")
plt.legend()
plt.show()

# ----------------------
# 13. Final Metrics
# ----------------------
print(f"Final ROC-AUC: {roc_auc:.4f}")
print(f"Final PR-AUC: {pr_auc:.4f}")
# Out:
# Dataset shape: (284807, 31)
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# Class weights: {0: np.float64(0.5008652375006595), 1: np.float64(289.4380081300813)}
# Training samples: 199364
# Test samples: 85443
# C:\Users\23adsb58\.conda\envs\61782323110058\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           3,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,105 (59.00 KB)
#  Trainable params: 14,721 (57.50 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/30
# 98/98 - 2s - 16ms/step - accuracy: 0.8705 - loss: 0.3519
# Epoch 2/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9656 - loss: 0.1803
# Epoch 3/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9680 - loss: 0.1425
# Epoch 4/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9682 - loss: 0.1239
# Epoch 5/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9677 - loss: 0.1196
# Epoch 6/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9708 - loss: 0.1083
# Epoch 7/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9735 - loss: 0.0948
# Epoch 8/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9713 - loss: 0.0944
# Epoch 9/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9729 - loss: 0.0879
# Epoch 10/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9720 - loss: 0.0786
# Epoch 11/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9735 - loss: 0.0805
# Epoch 12/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9783 - loss: 0.0883
# Epoch 13/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9766 - loss: 0.0654
# Epoch 14/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9769 - loss: 0.0747
# Epoch 15/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9747 - loss: 0.0666
# Epoch 16/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9756 - loss: 0.0755
# Epoch 17/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9745 - loss: 0.0692
# Epoch 18/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9769 - loss: 0.0756
# Epoch 19/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9821 - loss: 0.0572
# Epoch 20/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9761 - loss: 0.0752
# Epoch 21/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9732 - loss: 0.0622
# Epoch 22/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9777 - loss: 0.0637
# Epoch 23/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9732 - loss: 0.0622
# Epoch 24/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9787 - loss: 0.0587
# Epoch 25/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9795 - loss: 0.0476
# Epoch 26/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9810 - loss: 0.0559
# Epoch 27/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9752 - loss: 0.0517
# Epoch 28/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9852 - loss: 0.0411
# Epoch 29/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9808 - loss: 0.0477
# Epoch 30/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9789 - loss: 0.0515
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 1s 329us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9998    0.9870    0.9933     85295
#            1     0.1039    0.8716    0.1856       148
#
#     accuracy                         0.9868     85443
#    macro avg     0.5518    0.9293    0.5895     85443
# weighted avg     0.9982    0.9868    0.9919     85443
# Final ROC-AUC: 0.9702
# Final PR-AUC: 0.6787

# %%
# ======================================================
# Experiment 2: 70–30 Train–Test Split (No Validation)
# Credit Card Fraud Detection using DNN
# ======================================================

# ----------------------
# 1. Imports
# ----------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    average_precision_score
)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# ----------------------
# 2. Load Dataset (CSV)
# ----------------------
# Make sure creditcard.csv is in the same directory
df = pd.read_csv(r"C:\Users\23adsb58\Downloads\creditcard.csv")

print("Dataset shape:", df.shape)
print(df["Class"].value_counts())

# ----------------------
# 3. Feature / Target Split
# ----------------------
X = df.drop("Class", axis=1)
y = df["Class"]

# ----------------------
# 4. Feature Scaling
# ----------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ----------------------
# 5. Handle Class Imbalance (Class Weights)
# ----------------------
neg, pos = np.bincount(y)
total = neg + pos

class_weight = {
    0: total / (2 * neg),
    1: total / (2 * pos)
}

print("Class weights:", class_weight)

# ----------------------
# 6. Train–Test Split (70–30)
# ----------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.30,
    stratify=y,
    random_state=42
)

print("Training samples:", X_train.shape[0])
print("Test samples:", X_test.shape[0])

# ----------------------
# 7. Build Deep Neural Network
# ----------------------
def build_dnn():
    model = Sequential([
        Dense(128, activation="relu", input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(64, activation="relu"),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation="relu"),
        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

model_exp2 = build_dnn()
model_exp2.summary()

# ----------------------
# 8. Train Model
# ----------------------
history2 = model_exp2.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=2048,
    class_weight=class_weight,
    verbose=2
)

# ----------------------
# 9. Plot Training Loss
# ----------------------
plt.figure(figsize=(6,4))
plt.plot(history2.history["loss"], label="Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Experiment 2 (70–30) - Training Loss")
plt.legend()
plt.show()

# ----------------------
# 10. Model Evaluation
# ----------------------
y_pred_prob = model_exp2.predict(X_test).ravel()
y_pred = (y_pred_prob > 0.5).astype(int)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Experiment 2 - Confusion Matrix")
plt.show()

# ----------------------
# 11. ROC-AUC
# ----------------------
roc_auc = roc_auc_score(y_test, y_pred_prob)
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

plt.figure(figsize=(5,4))
plt.plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Experiment 2 - ROC Curve")
plt.legend()
plt.show()

# ----------------------
# 12. Precision–Recall AUC
# ----------------------
pr_auc = average_precision_score(y_test, y_pred_prob)
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)

plt.figure(figsize=(5,4))
plt.plot(recall, precision, label=f"PR-AUC = {pr_auc:.4f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Experiment 2 - Precision–Recall Curve")
plt.legend()
plt.show()

# ----------------------
# 13. Final Metrics
# ----------------------
print(f"Final ROC-AUC: {roc_auc:.4f}")
print(f"Final PR-AUC: {pr_auc:.4f}")
# Out:
# Dataset shape: (284807, 31)
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# Class weights: {0: np.float64(0.5008652375006595), 1: np.float64(289.4380081300813)}
# Training samples: 199364
# Test samples: 85443
# C:\Users\23adsb58\.conda\envs\61782323110058\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           3,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,105 (59.00 KB)
#  Trainable params: 14,721 (57.50 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/30
# 98/98 - 2s - 16ms/step - accuracy: 0.8705 - loss: 0.3519
# Epoch 2/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9656 - loss: 0.1803
# Epoch 3/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9680 - loss: 0.1425
# Epoch 4/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9682 - loss: 0.1239
# Epoch 5/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9677 - loss: 0.1196
# Epoch 6/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9708 - loss: 0.1083
# Epoch 7/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9735 - loss: 0.0948
# Epoch 8/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9713 - loss: 0.0944
# Epoch 9/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9729 - loss: 0.0879
# Epoch 10/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9720 - loss: 0.0786
# Epoch 11/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9735 - loss: 0.0805
# Epoch 12/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9783 - loss: 0.0883
# Epoch 13/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9766 - loss: 0.0654
# Epoch 14/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9769 - loss: 0.0747
# Epoch 15/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9747 - loss: 0.0666
# Epoch 16/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9756 - loss: 0.0755
# Epoch 17/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9745 - loss: 0.0692
# Epoch 18/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9769 - loss: 0.0756
# Epoch 19/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9821 - loss: 0.0572
# Epoch 20/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9761 - loss: 0.0752
# Epoch 21/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9732 - loss: 0.0622
# Epoch 22/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9777 - loss: 0.0637
# Epoch 23/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9732 - loss: 0.0622
# Epoch 24/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9787 - loss: 0.0587
# Epoch 25/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9795 - loss: 0.0476
# Epoch 26/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9810 - loss: 0.0559
# Epoch 27/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9752 - loss: 0.0517
# Epoch 28/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9852 - loss: 0.0411
# Epoch 29/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9808 - loss: 0.0477
# Epoch 30/30
# 98/98 - 1s - 6ms/step - accuracy: 0.9789 - loss: 0.0515
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 1s 329us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9998    0.9870    0.9933     85295
#            1     0.1039    0.8716    0.1856       148
#
#     accuracy                         0.9868     85443
#    macro avg     0.5518    0.9293    0.5895     85443
# weighted avg     0.9982    0.9868    0.9919     85443
# Final ROC-AUC: 0.9702
# Final PR-AUC: 0.6787
